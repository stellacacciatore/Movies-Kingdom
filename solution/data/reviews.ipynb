# %% [markdown]
# # ROTTEN_TOMATOES_REVIEWS.CSV CLEANING

# %%
import pandas as pd

# %%
data_directory = 'data_csv/'

reviews_df = pd.read_csv(data_directory+'rotten_tomatoes_reviews.csv')
reviews_df
# Out:
#         rotten_tomatoes_link  \
# 0                  m/0814255
# 1                  m/0814255
# 2                  m/0814255
# 3                  m/0814255
# 4                  m/0814255
# ...                      ...
# 1129882          m/zulu_dawn
# 1129883          m/zulu_dawn
# 1129884          m/zulu_dawn
# 1129885          m/zulu_dawn
# 1129886          m/zulu_dawn
#
#                                                movie_title        critic_name  \
# 0        Percy Jackson & the Olympians: The Lightning T...    Andrew L. Urban
# 1        Percy Jackson & the Olympians: The Lightning T...      Louise Keller
# 2        Percy Jackson & the Olympians: The Lightning T...                NaN
# 3        Percy Jackson & the Olympians: The Lightning T...       Ben McEachen
# 4        Percy Jackson & the Olympians: The Lightning T...        Ethan Alter
# ...                                                    ...                ...
# 1129882                                          Zulu Dawn      Chuck O'Leary
# 1129883                                          Zulu Dawn          Ken Hanke
# 1129884                                          Zulu Dawn    Dennis Schwartz
# 1129885                                          Zulu Dawn  Christopher Lloyd
# 1129886                                          Zulu Dawn     Brent McKnight
#
#          top_critic                   publisher_name review_type review_score  \
# 0             False                   Urban Cinefile       Fresh          NaN
# 1             False                   Urban Cinefile       Fresh          NaN
# 2             False              FILMINK (Australia)       Fresh          NaN
# 3             False          Sunday Mail (Australia)       Fresh        3.5/5
# 4              True               Hollywood Reporter      Rotten          NaN
# ...             ...                              ...         ...          ...
# 1129882       False                 Fantastica Daily      Rotten          2/5
# 1129883       False  Mountain Xpress (Asheville, NC)       Fresh        3.5/5
# 1129884       False    Dennis Schwartz Movie Reviews       Fresh           B+
# 1129885       False          Sarasota Herald-Tribune      Rotten        3.5/5
# 1129886       False             The Last Thing I See      Rotten            C
#
#         review_date                                     review_content
# 0        2010-02-06  A fantasy adventure that fuses Greek mythology...
# 1        2010-02-06  Uma Thurman as Medusa, the gorgon with a coiff...
# 2        2010-02-09  With a top-notch cast and dazzling special eff...
# 3        2010-02-09  Whether audiences will get behind The Lightnin...
# 4        2010-02-10  What's really lacking in The Lightning Thief i...
# ...             ...                                                ...
# 1129882  2005-11-02                                                NaN
# 1129883  2007-03-07  Seen today, it's not only a startling indictme...
# 1129884  2010-09-16  A rousing visual spectacle that's a prequel of...
# 1129885  2011-02-28  A simple two-act story: Prelude to war, and th...
# 1129886  2020-07-09  Rides the line between being a pure artifact o...
#
# [1129887 rows x 9 columns]

# %%
reviews_df.shape
# Out:
# (1129887, 9)

# %%
reviews_df.dtypes
# Out:
# rotten_tomatoes_link    object
# movie_title             object
# critic_name             object
# top_critic                bool
# publisher_name          object
# review_type             object
# review_score            object
# review_date             object
# review_content          object
# dtype: object

# %% [markdown]
# ## CHANGING TYPES OF OBJECT COLUMNS

# %%
reviews_df['movie_title'] = reviews_df['movie_title'].astype('string')
reviews_df['critic_name'] = reviews_df['critic_name'].astype('string')
reviews_df['publisher_name'] = reviews_df['publisher_name'].astype('string')
reviews_df['review_type'] = reviews_df['review_type'].astype('string')
reviews_df['review_score'] = reviews_df['review_score'].astype('string')
reviews_df['review_date'] = pd.to_datetime(reviews_df['review_date'], format="%Y-%m-%d")
reviews_df['review_content'] = reviews_df['review_content'].astype('string')
reviews_df.dtypes
# Out:
# rotten_tomatoes_link            object
# movie_title             string[python]
# critic_name             string[python]
# top_critic                        bool
# publisher_name          string[python]
# review_type             string[python]
# review_score            string[python]
# review_date             datetime64[ns]
# review_content          string[python]
# dtype: object

# %% [markdown]
# ## NOW WE TRY TO UNDERSTAND COLUMNS VALUES

# %%
columns_values = list(reviews_df.columns.values)
print(columns_values)
# Out:
# ['rotten_tomatoes_link', 'movie_title', 'critic_name', 'top_critic', 'publisher_name', 'review_type', 'review_score', 'review_date', 'review_content']

# %%
print(list(reviews_df['review_type'].unique()))
# Out:
# ['Fresh', 'Rotten']

# %% [markdown]
# Fresh: 60% and above – Indicates generally favorable reviews from critics.
#
# Rotten: Below 60% – Indicates generally unfavorable reviews from critics.

# %%
# is there a way to normalise these values?
types_of_score = list(reviews_df['review_score'].dropna().unique())
types_of_score.sort()
print(types_of_score)
# Out:
# ['0', '0.02/5', '0.05/4', '0.1/5', '0.13/1', '0.13/5', '0.2/5', '0.21/10', '0.25/4', '0.3/5', '0.4/5', '0.5/10', '0.5/4', '0.5/5', '0.5/5.5', '0.52/1', '0.58/1', '0.59/1', '0.6/1', '0.6/10', '0.65/10', '0.66/10', '0.664363/10', '0.666/4', '0.7221/10', '0.75/10', '0.75/5', '0.7765823/10', '0.8/10', '0.8/5', '0.81/1', '0.82/10', '0.85/10', '0.9/10', '0.96/10', '0/10', '0/100', '0/1000', '0/4', '0/5', '0/6', '1', '1.1/10', '1.1/2', '1.1/5', '1.2/10', '1.2/4', '1.2/5', '1.21/10', '1.24/5', '1.25/4', '1.25/5', '1.3/5', '1.35/5', '1.4/10', '1.4/4', '1.4/5', '1.5/10', '1.5/2', '1.5/3', '1.5/4', '1.5/5', '1.5/6', '1.5242228/10', '1.6/5', '1.62/5', '1.7/5', '1.75/10', '1.75/4', '1.75/5', '1.8/10', '1.8/4', '1.8/5', '1.82/10', '1.85/10', '1.88/10', '1.9/10', '1.9/5', '1.9528/10', '1/1', '1/10', '1/2', '1/3', '1/4', '1/5', '1/54', '1/6', '10', '10.50/20', '10/10', '10/100', '10/20', '10/90', '100/100', '11.5/20', '11/100', '11/20', '12.5/20', '12.50/20', '12/100', '12/20', '13.5/20', '13/100', '13/20', '14', '14.5/20', '14.50/20', '14/100', '14/20', '15.5/20', '15/100', '15/20', '16.5/20', '16/100', '16/20', '17.5/20', '17/20', '18.5/20', '18/100', '18/20', '19/100', '19/20', '2', '2.1/10', '2.1/2', '2.1/5', '2.11/5', '2.12/5', '2.2/10', '2.2/5', '2.20282652/10', '2.212521/10', '2.25/4', '2.25/5', '2.255/5', '2.282303/10', '2.3/10', '2.3/4', '2.3/5', '2.4/10', '2.4/4', '2.4/5', '2.5/10', '2.5/20', '2.5/3', '2.5/4', '2.5/5', '2.5/50', '2.5/6', '2.50/5', '2.55/4', '2.55/5', '2.6/10', '2.6/4', '2.6/5', '2.6/6', '2.65/10', '2.7/10', '2.7/4', '2.7/5', '2.74/10', '2.75/10', '2.75/3', '2.75/4', '2.75/5', '2.8/10', '2.8/4', '2.8/5', '2.83/5', '2.85/5', '2.89/5', '2.892521821/10', '2.9/10', '2.9/5', '2.95/10', '2.95/5', '2/10', '2/100', '2/2', '2/20', '2/3', '2/4', '2/5', '2/54', '2/6', '2/8', '2/9', '20/100', '20/20', '21/100', '21/24', '22/100', '23/100', '24', '24/100', '25', '25/100', '25/4', '26/100', '27/100', '28/100', '29/100', '3', '3.021/10', '3.0782/10', '3.1/10', '3.1/5', '3.15/5', '3.2/10', '3.2/4', '3.2/5', '3.20/10', '3.2121/10', '3.222423/10', '3.25/10', '3.25/4', '3.25/5', '3.3/10', '3.3/4', '3.3/5', '3.35/5', '3.4/10', '3.4/4', '3.4/5', '3.45/5', '3.5/10', '3.5/18', '3.5/20', '3.5/3', '3.5/4', '3.5/44', '3.5/5', '3.5/5.5', '3.5/6', '3.515/10', '3.54/5', '3.55/10', '3.56339/10', '3.6/10', '3.6/4', '3.6/5', '3.65/10', '3.65/5', '3.7/10', '3.7/5', '3.75/10', '3.75/4', '3.75/5', '3.7521/10', '3.76/10', '3.76/5', '3.7822391/10', '3.8/10', '3.8/5', '3.83412437/10', '3.85/10', '3.9/10', '3.9/5', '3.99/10', '3/10', '3/100', '3/20', '3/3', '3/4', '3/40', '3/45', '3/5', '3/5.4', '3/5.5', '3/6', '30/100', '31/100', '32/100', '33/100', '34', '34/100', '35', '35/100', '35/4', '36/100', '37/100', '38/100', '39/100', '39/40', '4', '4.0001/10', '4.021/10', '4.05524/10', '4.1/10', '4.1/5', '4.143641/10', '4.2/10', '4.2/5', '4.21/10', '4.211/10', '4.2112/10', '4.21382343/10', '4.22/10', '4.25/10', '4.25/5', '4.293382/10', '4.3/10', '4.3/5', '4.35/10', '4.35/5', '4.364221/10', '4.4/10', '4.4/5', '4.42/10', '4.45/10', '4.5/10', '4.5/4', '4.5/5', '4.5/6', '4.51/10', '4.521/10', '4.55/10', '4.558/10', '4.56/10', '4.6/10', '4.6/5', '4.65/10', '4.65/5', '4.7/10', '4.7/5', '4.70/10', '4.75/10', '4.75/5', '4.79/10', '4.8/10', '4.8/5', '4.827/10', '4.85/10', '4.86/10', '4.89/10', '4.89215/10', '4.9/10', '4.90/10', '4.95/10', '4.95/5', '4.9834326/10', '4.9837/10', '4/0', '4/10', '4/100', '4/3.5', '4/4', '4/5', '4/5.5', '4/6', '4/8', '40/100', '41/100', '42/100', '43/100', '44/100', '45', '45/100', '45/5', '46', '46/100', '47/100', '47/50', '48', '48/100', '49/100', '5', '5.01/10', '5.02120621/10', '5.046/10', '5.05/10', '5.1/10', '5.10/10', '5.12/10', '5.1221/10', '5.15/10', '5.1921/10', '5.2/10', '5.21/10', '5.212/10', '5.22/10', '5.23/10', '5.232121/10', '5.25/10', '5.284849/10', '5.3/10', '5.35/10', '5.4/10', '5.4221/10', '5.44/10', '5.45/10', '5.48/10', '5.49/10', '5.5/10', '5.5/20', '5.5/5', '5.5/6', '5.50/10', '5.51/10', '5.55/10', '5.5542/10', '5.56 ...

# %% [markdown]
# these scores are confusing. Rotten Tomatoes aggregates review scores from a variety of sources, including professional critics, publications, and audience ratings, which means each critic may use different types of rating, such as:
# - letters: A, B, C etc.
# - numbers: 2, 10, 77 etc.
# - fractions: 4/5, 2/3, 10/90 etc.

# %%
reviews_df.loc[:, 'review_score'] = reviews_df['review_score'].str.replace(' ', '')

# %%
def normalize_score(score):

    if isinstance(score, str):
        # case when there's a denominator
        if '/' in score:
            num, den = map(float, score.split('/'))
            if den == 0: # if the num has 0 as denominator
                return num
            return (num / den) * 100
        elif score.isnumeric():
            return score

        letter_grades = { # normalise letters into nums
            'A+': 100, 'A': 95, 'A-': 90,
            'B+': 85, 'B': 80, 'B-': 75,
            'C+': 70, 'C': 65, 'C-': 60,
            'D+': 55, 'D': 50, 'D-': 45,
            'F': 30
        }
        return letter_grades.get(score)

# %%
reviews_df['normalized_review_score'] = reviews_df['review_score'].apply(normalize_score)
reviews_df['normalized_review_score'] = reviews_df['normalized_review_score'].astype(float)

# %% [markdown]
# ## ARE THERE NA VALUES IN THE DATASET?

# %%
not_available_links = reviews_df['rotten_tomatoes_link'].isna().sum()
not_available_movie_titles = reviews_df['movie_title'].isna().sum()
not_available_critic_name = reviews_df['critic_name'].isna().sum()
not_available_top_critic = reviews_df['top_critic'].isna().sum()
not_available_publisher_name = reviews_df['publisher_name'].isna().sum()
not_available_review_type = reviews_df['review_type'].isna().sum()
not_available_review_score = reviews_df['review_score'].isna().sum()
not_available_normalized_view_score = reviews_df['normalized_review_score'].isna().sum()
not_available_review_date = reviews_df['review_date'].isna().sum()
not_available_review_content = reviews_df['review_content'].isna().sum()

# %%
print('Not available links: ', not_available_links,
      '\nNot available movie titles: ', not_available_movie_titles,
      '\nNot available critic name: ', not_available_critic_name,
      '\nNot available top critic: ', not_available_top_critic,
      '\nNot available publisher: ', not_available_publisher_name,
      '\nNot available review type: ', not_available_review_type,
      '\nNot available review score: ', not_available_review_score,
      '\nNot available normalized review score: ', not_available_normalized_view_score,
      '\nNot available review date: ', not_available_review_date,
      '\nNot available review content: ', not_available_review_content)
# Out:
# Not available links:  0
# Not available movie titles:  0
# Not available critic name:  18521
# Not available top critic:  0
# Not available publisher:  0
# Not available review type:  0
# Not available review score:  305902
# Not available normalized review score:  305902
# Not available review date:  0
# Not available review content:  65778

# %% [markdown]
# ## ARE THERE ANY DUPLICATES?

# %%
num_duplicated_reviews = reviews_df.duplicated().sum()
print('There are a total of {} duplicates'.format(num_duplicated_reviews))
# Out:
# There are a total of 119471 duplicates

# %%
reviews_df.loc[reviews_df.duplicated(keep=False)]
# Out:
#                                       rotten_tomatoes_link  \
# 35513                                  m/1069696-screamers
# 35514                                  m/1069696-screamers
# 35576                                    m/1069707-othello
# 35577                                    m/1069707-othello
# 41315                    m/1087935-buena_vista_social_club
# ...                                                    ...
# 955042   m/the_fog_of_war_eleven_lessons_from_the_life_...
# 959360              m/the_girl_with_the_dragon_tattoo_2009
# 959361              m/the_girl_with_the_dragon_tattoo_2009
# 1044907                                    m/together_2001
# 1044908                                    m/together_2001
#
#                                                movie_title critic_name  \
# 35513                                            Screamers  Dave White
# 35514                                            Screamers  Dave White
# 35576                                              Othello  Fred Topel
# 35577                                              Othello  Fred Topel
# 41315                              Buena Vista Social Club        <NA>
# ...                                                    ...         ...
# 955042   The Fog of War: Eleven Lessons from the Life o...        <NA>
# 959360                     The Girl with the Dragon Tattoo        <NA>
# 959361                     The Girl with the Dragon Tattoo        <NA>
# 1044907                                           Together        <NA>
# 1044908                                           Together        <NA>
#
#          top_critic publisher_name review_type review_score review_date  \
# 35513         False     Movies.com       Fresh           B-  1996-01-26
# 35514         False     Movies.com       Fresh           B-  1996-01-26
# 35576         False      About.com       Fresh          4/5  2003-11-25
# 35577         False      About.com       Fresh          4/5  2003-11-25
# 41315         False    Film Threat       Fresh          4/5  2002-12-08
# ...             ...            ...         ...          ...         ...
# 955042        False    Film Threat       Fresh          4/5  2005-12-06
# 959360        False  National Post       Fresh        3.5/4  2009-02-27
# 959361        False  National Post       Fresh        3.5/4  2009-02-27
# 1044907       False    Film Threat       Fresh          4/5  2002-12-08
# 1044908       False    Film Threat       Fresh          4/5  2002-12-08
#
#                       review_content  normalized_review_score
# 35513                           <NA>                     75.0
# 35514                           <NA>                     75.0
# 35576    Fine Shakespeare adaptation                     80.0
# 35577    Fine Shakespeare adaptation                     80.0
# 41315                           <NA>                     80.0
# ...                              ...                      ...
# 955042                          <NA>                     80.0
# 959360                          <NA>                     87.5
# 959361                          <NA>                     87.5
# 1044907                         <NA>                     80.0
# 1044908                         <NA>                     80.0
#
# [238926 rows x 10 columns]

# %%
reviews_df = reviews_df[~reviews_df.duplicated()]
reviews_df.loc[reviews_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [rotten_tomatoes_link, movie_title, critic_name, top_critic, publisher_name, review_type, review_score, review_date, review_content, normalized_review_score]
# Index: []

# %%
reviews_df.loc[35513]
# Out:
# rotten_tomatoes_link       m/1069696-screamers
# movie_title                          Screamers
# critic_name                         Dave White
# top_critic                               False
# publisher_name                      Movies.com
# review_type                              Fresh
# review_score                                B-
# review_date                1996-01-26 00:00:00
# review_content                            <NA>
# normalized_review_score                   75.0
# Name: 35513, dtype: object

# %% [markdown]
# ## ARE THERE ANY UNREASONABLE VALUES?

# %%
bigger_than_100 = reviews_df[reviews_df['normalized_review_score'] > 100]
bigger_than_100
# Out:
#                        rotten_tomatoes_link  \
# 44843                    m/1098652-in_crowd
# 111377                          m/adoration
# 112814                         m/affliction
# 126588                    m/american_beauty
# 152047             m/avengers_age_of_ultron
# 190365                    m/bless_the_child
# 201589                         m/boy_erased
# 202512                      m/boys_dont_cry
# 238191                    m/children_of_men
# 238833                       m/chill_factor
# 336986      m/fast_cheap_and_out_of_control
# 359236                    m/freedom_writers
# 379580                          m/godfather
# 453642   m/inmate_1_the_rise_of_danny_trejo
# 462329             m/is_there_anybody_there
# 490080                    m/kill_bill_vol_1
# 503524                          m/lady_bird
# 556085                      m/marley_and_me
# 565895                       m/megan_leavey
# 607697      m/never_rarely_sometimes_always
# 646704                     m/pawn_sacrifice
# 669816                         m/pride_2014
# 680197                       m/pulp_fiction
# 682688               m/pursuit_of_happyness
# 765859                    m/schindlers_list
# 819852                            m/skyfall
# 832780                            m/sobibor
# 886523                     m/straight_story
# 893989                        m/suffragette
# 920179             m/the-eagle-of-the-ninth
# 922889                m/the_accountant_2016
# 941807                    m/the_dark_knight
# 944688                   m/the_details_2010
# 948947       m/the_emperor_and_the_assassin
# 961130                    m/the_grandmaster
# 979009                     m/the_judge_2014
# 987946           m/the_little_stranger_2018
# 1000103           m/the_old_man_and_the_gun
# 1068829                   m/unfinished_song
# 1078989                           m/vertigo
#
#                                                movie_title  \
# 44843                                         The In Crowd
# 111377                                           Adoration
# 112814                                          Affliction
# 126588                                     American Beauty
# 152047                             Avengers: Age of Ultron
# 190365                                     Bless the Child
# 201589                                          Boy Erased
# 202512                                      Boys Don't Cry
# 238191                                     Children of Men
# 238833                                        Chill Factor
# 336986                        Fast, Cheap & Out of Control
# 359236                                     Freedom Writers
# 379580                                       The Godfather
# 453642                  Inmate #1: The Rise of Danny Trejo
# 462329                                   Is Anybody There?
# 490080                                 Kill Bill: Volume 1
# 503524                                           Lady Bird
# 556085                                         Marley & Me
# 565895                                        Megan Leavey
# 607697                       Never Rarely Sometimes Always
# 646704                                      Pawn Sacrifice
# 669816                                               Pride
# 680197                                        Pulp Fiction
# 682688                            The Pursuit of Happyness
# 765859                                    Schindler's List
# 819852                                             Skyfall
# 832780                                             Sobibor
# 886523                                  The Straight Story
# 893989                                         Suffragette
# 920179                                           The Eagle
# 922889                                      The Accountant
# 941807                                     The Dark Knight
# 944688                                         The Details
# 948947   The Emperor and the Assassin (Jing Ke ci Qin W...
# 961130                                     The Grandmaster
# 979009                                           The Judge
# 987946                                 The Little Stranger
# 1000103                              The Old Man & the Gun
# 1068829                                    Unfinished Song
# 1078989                                            Vertigo
#
#                   critic_name  top_critic              publisher_name  \
# 44843          Scott A. Mantz       False  Scott Mantz' Movie Reviews
# 111377              Pam Grady       False          Boxoffice Magazine
# 112814          Russell Smith       False            Austin Chronicle
# 126588         Scott A. Mantz       False  Scott Mantz' Movie Reviews
# 152047        Kevin A. Ranson       False              MovieCrypt.com
# 190365         Scott A. Mantz       False  Scott Mantz' Movie Reviews
# 201589     Tiffany Tchobanian       False                 Film Threat
# 202512    Marjorie Baumgarten       False            Austin Chronicle
# 238191       Lawrence Toppman       False          Charlotte Observer
# 238833         Scott A. Mantz       False  Scott Mantz' Movie Reviews
# 336986    Marjorie Baumgarten       False            Austin Chronicle
# 359236          John Anderson        True                     Newsday
# 379580    Marjorie Baumgarten       False            Austin Chronicle
# 453642   Sarah Knight Adamson       False      Sarah's Backstage Pass
# 462329          Leigh Paatsch       False      Herald Sun (Australia)
# 490080                   <NA>       False    Sunday Times (Australia)
# 503524             Di Golding       False          Dear Cast and Crew
# 556085           Sean Gandert       False              Paste Magazine
# 565895          Philip Martin       False   Arkansas Democrat-Gazette
# 607697   Sarah Knight Adamson       False      Sarah's Backstage Pass
# 646704            Uriel Barco       False                      Garuyo
# 669816          Sean P. Means       False           Salt Lake Tribune
# 680197    Marjorie Baumgarten       False            Austin Chronicle
# 682688         Johnny Vaughan       False                The Sun (UK)
# 765859    Marjorie Baumgarten       False            Austin Chronicle
# 819852            Roger Moore       False        Tribune News Service
# 832780         Mark R. Leeper       False       Mark Leeper's Reviews
# 886523             Mike Emery       False            Austin Chronicle
# 893989            Tony Medley       False               Tolucan Times
# 920179   Radheyan Simonpillai       False                  AskMen.com
# 922889            Tony Medley       False               Tolucan Times
# 941807         Kevin McCarthy       False         WJFK-FM (CBS Radio)
# 944688            Roger Moore       False        Tribune News Service
# 948947    Marjorie Baumgarten       False            Austin Chronicle
# 961130         Leonard Maltin       False           leonardmaltin.com
# 979009            Tony Medley       False               Tolucan Times
# 987946         Eric Eisenberg       False                 CinemaBlend
# 1000103           Abby Olcese       False                Rave Reviews
# 1068829        Leonard Maltin       False           leonardmaltin.com
# 1078989   Marjorie Baumgarten       False            Austin Chronicle
#
#         review_type review_score review_date  \
# 44843        Rotten          7/5  2000-01-01
# 111377        Fresh        4.5/4  2009-04-23
# 112814        Fresh        5.5/5  2000-01-01
# 126588        Fresh          9/5  2000-01-01
# 152047        Fresh        3.5/3  2015-05-03
# 190365       Rotten          8/5  2000-01-01
# 201589        Fresh        9.5/5  2018-10-16
# 202512        Fresh        5.5/5  2000-01-01
# 238191        Fresh         35/4  2007-01-04
# 238833       Rotten          9/5  2000-01-01
# 336986        Fresh        5.5/5  2000-01-01
# 359236        Fresh         35/4  2007-01-04
# 379580        Fresh        5.5/5  2000-01-01
# 453642        Fresh        4/3.5  2020-07-10
# 462329       Rotten        5.5/5  2009-05-27
# 490080        Fresh        4.5/4  2003-10-23
# 503524        Fresh        4.5/4  2018-12-07
# 556085        Fresh        67/10  2009-01-05
# 565895        Fresh        87/10  2017-06-09
# 607697        Fresh        4/3.5  2020-04-03
# 646704        Fresh        8.5/5  2016-02-28
# 669816        Fresh         35/4  2015-01-05
# 680197        Fresh        5.5/5  2000-01-01
# 682688        Fresh        4.5/4  2007-01-14
# 765859        Fresh        5.5/5  2000-01-01
# 819852        Fresh         35/4  2012-11-08
# 832780        Fresh          920  2019-04-28
# 886523        Fresh        5.5/5  2000-01-01
# 893989       Rotten        76/10  2015-10-27
# 920179        Fresh        75/10  2011-02-11
# 922889        Fresh          910  2016-10-17
# 941807        Fresh          6/5  2008-07-17
# 944688        Fresh         25/4  2012-11-01
# 948947        Fresh        5.5/5  2000-01-01
# 961130       Rotten        2.1/2  2013-08-23
# 979009        Fresh          910  2014-10-10
# 987946        Fresh         45/5  2018-09-01
# 1000103       Fresh        73/10  2019-03-18
# 1068829       Fresh        2.1/2  2013-06-21
# 1078989       Fresh        5.5/5  2000-01-01
#
#                                             review_content  \
# 44843    If you're looking for an engaging movie with c...
# 111377                           Egoyan's finest in years.
# 112814                                                <NA>
# 126588   You can't help but wonder how people find them...
# 152047   ... tops the original ... yet, somehow it felt...
# 190365   Considering how jaded moviegoers are these day...
# 201589   Boy Erased is a poignant family drama that exp...
# 202512                                                <NA>
# 238191   It's as if Cuaron sees a future so hellish tha...
# 238833   Cuba, got a minute? We've gotta talk! Your car...
# 336986                                                <NA>
# 359236   Freedom Writers takes plenty of shots at the s...
# 379580   So many great roles and characters in this mov...
# 453642   The film comes from the heart, it's a raw, upl...
# 462329   Director John Crowley overestimates the comedi...
# 490080                                                <NA>
# 503524   Greta Gerwig, in her first time out of the gat...
# 556085   It dips a little too deeply into unnecessary s...
# 565895   It's hard not to like a good old-fashioned, dr...
# 607697   The powerful, enlightening "Never, Rarely, Som...
# 646704   A movie about victory, loss, paranoia, and tol...
# 669816   The script's many small moments are catnip for...
# 680197   Rarely have I left a movie theatre more thrill...
# 682688   The on-screen chemistry between father and son...
# 765859   Spielberg marshals all his formidable storytel...
# 819852   Gets Bond back to the basics: bullets, babes, ...
# 832780   While the entire film has been downbeat (to sa...
# 886523   What Lynch goes for here is a brilliant odysse...
# 893989   ...tells a true story with mostly fictional ch...
# 920179   The material here verges on camp, but director...
# 922889   ...a well done thriller that does not lag...wi...
# 941807   Ledger's performance reigns over Nicholson's b...
# 944688   Maguire, given the chance to play "a dirty phi...
# 948947                                                <NA>
# 961130   Wong Kar Wai's new epic The Grandmaster is an ...
# 979009   Finally Robert Downey gets an intelligent scri...
# 987946   It's deliberate in its storytelling, and may n...
# 1000103  The Old Man and the Gun isn't here to rock the...
# 1068829  I can't fault the actors or their performances...
# 1078989  Vertigo stands as one of the thrill master's m...
#
#          normalized_review_score
# 44843                 140.000000
# 111377                112.500000
# 112814                110.000000
# 126588                180.000000
# 152047                116.666667
# 190365                160.000000
# 201589                190.000000
# 202512                110.000000
# 238191                875.000000
# 238833                180.000000
# 336986                110.000000
# 359236                875.000000
# 379580                110.000000
# 453642                114.285714
# 462329                110.000000
# 490080                112.500000
# 503524                112.500000
# 556085                670.000000
# 565895                870.000000
# 607697                114.285714
# 646704                170.000000
# 669816                875.000000
# 680197                110.000000
# 682688                112.500000
# 765859                110.000000
# 819852                875.000000
# 832780                920.000000
# 886523                110.000000
# 893989                760.000000
# 920179                750.000000
# 922889                910.000000
# 941807                120.000000
# 944688                625.000000
# 948947                110.000000
# 961130                105.000000
# 979009                910.000000
# 987946                900.000000
# 1000103               730.000000
# 1068829               105.000000
# 1078989               110.000000

# %% [markdown]
# there are some wrongly typed fractions which lead to a normalized score bigger than what it should be (we are normalizing using /100)

# %%
# should we delete those values or round it to 100?
print('There are {} values which are bigger than 100.'.format(bigger_than_100['normalized_review_score'].count()))
print('On the other hand, there are {} values in total in the column.'.format(reviews_df['normalized_review_score'].count()))
# Out:
# There are 40 values which are bigger than 100.
# On the other hand, there are 736845 values in total in the column.

# %% [markdown]
# from the prospective of a data analysis, losing 40 values is not that much since there are a lot more values to analyse, hence they are not that significative to our purpose. We could remove them and leave a NaN, since inserting a default value could result in unexpected outcomes.

# %%
import numpy as np
reviews_df.loc[reviews_df['normalized_review_score'] > 100, 'normalized_review_score'] = np.nan
reviews_df.loc[reviews_df['normalized_review_score'] > 100]
# Out:
# Empty DataFrame
# Columns: [rotten_tomatoes_link, movie_title, critic_name, top_critic, publisher_name, review_type, review_score, review_date, review_content, normalized_review_score]
# Index: []

# %%
reviews_df
# Out:
#         rotten_tomatoes_link  \
# 0                  m/0814255
# 1                  m/0814255
# 2                  m/0814255
# 3                  m/0814255
# 4                  m/0814255
# ...                      ...
# 1129882          m/zulu_dawn
# 1129883          m/zulu_dawn
# 1129884          m/zulu_dawn
# 1129885          m/zulu_dawn
# 1129886          m/zulu_dawn
#
#                                                movie_title        critic_name  \
# 0        Percy Jackson & the Olympians: The Lightning T...    Andrew L. Urban
# 1        Percy Jackson & the Olympians: The Lightning T...      Louise Keller
# 2        Percy Jackson & the Olympians: The Lightning T...               <NA>
# 3        Percy Jackson & the Olympians: The Lightning T...       Ben McEachen
# 4        Percy Jackson & the Olympians: The Lightning T...        Ethan Alter
# ...                                                    ...                ...
# 1129882                                          Zulu Dawn      Chuck O'Leary
# 1129883                                          Zulu Dawn          Ken Hanke
# 1129884                                          Zulu Dawn    Dennis Schwartz
# 1129885                                          Zulu Dawn  Christopher Lloyd
# 1129886                                          Zulu Dawn     Brent McKnight
#
#          top_critic                   publisher_name review_type review_score  \
# 0             False                   Urban Cinefile       Fresh         <NA>
# 1             False                   Urban Cinefile       Fresh         <NA>
# 2             False              FILMINK (Australia)       Fresh         <NA>
# 3             False          Sunday Mail (Australia)       Fresh        3.5/5
# 4              True               Hollywood Reporter      Rotten         <NA>
# ...             ...                              ...         ...          ...
# 1129882       False                 Fantastica Daily      Rotten          2/5
# 1129883       False  Mountain Xpress (Asheville, NC)       Fresh        3.5/5
# 1129884       False    Dennis Schwartz Movie Reviews       Fresh           B+
# 1129885       False          Sarasota Herald-Tribune      Rotten        3.5/5
# 1129886       False             The Last Thing I See      Rotten            C
#
#         review_date                                     review_content  \
# 0        2010-02-06  A fantasy adventure that fuses Greek mythology...
# 1        2010-02-06  Uma Thurman as Medusa, the gorgon with a coiff...
# 2        2010-02-09  With a top-notch cast and dazzling special eff...
# 3        2010-02-09  Whether audiences will get behind The Lightnin...
# 4        2010-02-10  What's really lacking in The Lightning Thief i...
# ...             ...                                                ...
# 1129882  2005-11-02                                               <NA>
# 1129883  2007-03-07  Seen today, it's not only a startling indictme...
# 1129884  2010-09-16  A rousing visual spectacle that's a prequel of...
# 1129885  2011-02-28  A simple two-act story: Prelude to war, and th...
# 1129886  2020-07-09  Rides the line between being a pure artifact o...
#
#          normalized_review_score
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                           70.0
# 4                            NaN
# ...                          ...
# 1129882                     40.0
# 1129883                     70.0
# 1129884                     85.0
# 1129885                     70.0
# 1129886                     65.0
#
# [1010416 rows x 10 columns]

# %%
print(reviews_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1010416 entries, 0 to 1129886
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   rotten_tomatoes_link     1010416 non-null  object
#  1   movie_title              1010416 non-null  string
#  2   critic_name              993970 non-null   string
#  3   top_critic               1010416 non-null  bool
#  4   publisher_name           1010416 non-null  string
#  5   review_type              1010416 non-null  string
#  6   review_score             736845 non-null   string
#  7   review_date              1010416 non-null  datetime64[ns]
#  8   review_content           951918 non-null   string
#  9   normalized_review_score  736805 non-null   float64
# dtypes: bool(1), datetime64[ns](1), float64(1), object(1), string(6)
# memory usage: 78.1+ MB
# None

# %% [markdown]
# ## SAVING THE CLEANED DATASET

# %%
reviews_df.to_csv('data_cleaned/reviews_cleaned.csv', index=False)

# %%
reviews_df = None
