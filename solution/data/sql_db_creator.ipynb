# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
df = pd.read_csv('data_cleaned/movies_cleaned.csv')

engine = create_engine('postgresql://postgres:postgres@localhost:5432/postgres')

df.to_sql('movie', engine, if_exists='replace', index=False)
# Out:
# 597

# %%
df = pd.read_csv('data_cleaned/posters_cleaned.csv')

engine = create_engine('postgresql://postgres:postgres@localhost:5432/postgres')

df.to_sql('posters', engine, if_exists='replace', index=False)
# Out:
# 597

# %%
df = pd.read_csv('data_cleaned/actors_cleaned.csv')

engine = create_engine('postgresql://postgres:postgres@localhost:5432/postgres')

df.to_sql('actors', engine, if_exists='replace', index=False)
# Out:
# 504

# %%
df = pd.read_csv('data_cleaned/oscar_awards_cleaned.csv')

engine = create_engine('postgresql://postgres:postgres@localhost:5432/postgres')

df.to_sql('oscars', engine, if_exists='replace', index=False)
# Out:
# 882

# %%
df = pd.read_csv('data_cleaned/genres_cleaned.csv')

engine = create_engine('postgresql://postgres:postgres@localhost:5432/postgres')

df.to_sql('genres', engine, if_exists='replace', index=False)
# Out:
# 849

# %%
df = pd.read_csv('data_cleaned/releases_cleaned.csv')

engine = create_engine('postgresql://postgres:postgres@localhost:5432/postgres')

df.to_sql('releases', engine, if_exists='replace', index=False)
# Out:
# 196

# %%
df = pd.read_csv('data_cleaned/studios_cleaned.csv')

engine = create_engine('postgresql://postgres:postgres@localhost:5432/postgres')

df.to_sql('studios', engine, if_exists='replace', index=False)
# Out:
# 71

# %%
df = pd.read_csv('data_cleaned/themes_cleaned.csv')

engine = create_engine('postgresql://postgres:postgres@localhost:5432/postgres')

df.to_sql('themes', engine, if_exists='replace', index=False)
# Out:
# 641

# %%
df = pd.read_csv('data_cleaned/crew_cleaned.csv')

engine = create_engine('postgresql://postgres:postgres@localhost:5432/postgres')

df.to_sql('crew', engine, if_exists='replace', index=False)
# Out:
# 901

# %%
df = pd.read_csv('data_cleaned/languages_cleaned.csv')

engine = create_engine('postgresql://postgres:postgres@localhost:5432/postgres')

df.to_sql('languages', engine, if_exists='replace', index=False)
# Out:
# 762
